# %%
# from 

from langchain.agents.agent_types import AgentType
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain_openai import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.agents.agent_types import AgentType
#       2 from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
#       3 from langchain_openai import ChatOpenAI
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain/agents/__init__.py:36
#      33 from typing import TYPE_CHECKING, Any
#      35 from langchain_core._api.path import as_import_path
# ---> 36 from langchain_core.tools import Tool
#      37 from langchain_core.tools.convert import tool
#      39 from langchain._api import create_importer
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/tools/__init__.py:22
#       1 """**Tools** are classes that an Agent uses to interact with the world.
#       2
#       3 Each tool has a **description**. Agent uses the description to choose the right
#    (...)
#      17     CallbackManagerForToolRun, AsyncCallbackManagerForToolRun
#      18 """  # noqa: E501
#      20 from __future__ import annotations
# ---> 22 from langchain_core.tools.base import (
#      23     FILTERED_ARGS as FILTERED_ARGS,
#      24 )
#      25 from langchain_core.tools.base import (
#      26     BaseTool as BaseTool,
#      27 )
#      28 from langchain_core.tools.base import (
#      29     BaseToolkit as BaseToolkit,
#      30 )
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/tools/base.py:30
#      27 from typing_extensions import Annotated, TypeVar, get_args, get_origin
#      29 from langchain_core._api import deprecated
# ---> 30 from langchain_core.callbacks import (
#      31     AsyncCallbackManager,
#      32     BaseCallbackManager,
#      33     CallbackManager,
#      34     Callbacks,
#      35 )
#      36 from langchain_core.load import Serializable
#      37 from langchain_core.messages import ToolCall, ToolMessage
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/callbacks/__init__.py:22
#       1 """**Callback handlers** allow listening to events in LangChain.
#       2
#       3 **Class hierarchy:**
#    (...)
#       7     BaseCallbackHandler --> <name>CallbackHandler  # Example: AimCallbackHandler
#       8 """
#      10 from langchain_core.callbacks.base import (
#      11     AsyncCallbackHandler,
#      12     BaseCallbackHandler,
#    (...)
#      20     ToolManagerMixin,
#      21 )
# ---> 22 from langchain_core.callbacks.file import FileCallbackHandler
#      23 from langchain_core.callbacks.manager import (
#      24     AsyncCallbackManager,
#      25     AsyncCallbackManagerForChainGroup,
#    (...)
#      42     dispatch_custom_event,
#      43 )
#      44 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/callbacks/file.py:7
#       3 from __future__ import annotations
#       5 from typing import Any, Dict, Optional, TextIO, cast
# ----> 7 from langchain_core.agents import AgentAction, AgentFinish
#       8 from langchain_core.callbacks import BaseCallbackHandler
#       9 from langchain_core.utils.input import print_text
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/agents.py:31
#      28 from typing import Any, List, Literal, Sequence, Union
#      30 from langchain_core.load.serializable import Serializable
# ---> 31 from langchain_core.messages import (
#      32     AIMessage,
#      33     BaseMessage,
#      34     FunctionMessage,
#      35     HumanMessage,
#      36 )
#      39 class AgentAction(Serializable):
#      40     """Represents a request to execute an action by an agent.
#      41
#      42     The action consists of the name of the tool to execute and the input to pass
#      43     to the tool. The log is used to pass along extra information about the action.
#      44     """
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/messages/__init__.py:18
#       1 """**Messages** are objects used in prompts and chat conversations.
#       2
#       3 **Class hierarchy:**
#    (...)
#      15
#      16 """  # noqa: E501
# ---> 18 from langchain_core.messages.ai import (
#      19     AIMessage,
#      20     AIMessageChunk,
#      21 )
#      22 from langchain_core.messages.base import (
#      23     BaseMessage,
#      24     BaseMessageChunk,
#    (...)
#      27     messages_to_dict,
#      28 )
#      29 from langchain_core.messages.chat import ChatMessage, ChatMessageChunk
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/messages/ai.py:11
#       4 from typing_extensions import TypedDict
#       6 from langchain_core.messages.base import (
#       7     BaseMessage,
#       8     BaseMessageChunk,
#       9     merge_content,
#      10 )
# ---> 11 from langchain_core.messages.tool import (
#      12     InvalidToolCall,
#      13     ToolCall,
#      14     ToolCallChunk,
#      15     default_tool_chunk_parser,
#      16     default_tool_parser,
#      17 )
#      18 from langchain_core.messages.tool import (
#      19     invalid_tool_call as create_invalid_tool_call,
#      20 )
#      21 from langchain_core.messages.tool import (
#      22     tool_call as create_tool_call,
#      23 )
#
# File ~/Library/Python/3.8/lib/python/site-packages/langchain_core/messages/tool.py:10
#       6 from langchain_core.messages.base import BaseMessage, BaseMessageChunk, merge_content
#       7 from langchain_core.utils._merge import merge_dicts, merge_obj
# ---> 10 class ToolMessage(BaseMessage):
#      11     """Message for passing the result of executing a tool back to a model.
#      12
#      13     ToolMessages contain the result of a tool invocation. Typically, the result
#    (...)
#      48     to request multiple tool calls in parallel.
#      49     """  # noqa: E501
#      51     tool_call_id: str
#
# File ~/Library/Python/3.8/lib/python/site-packages/pydantic/main.py:197, in pydantic.main.ModelMetaclass.__new__()
#
# File ~/Library/Python/3.8/lib/python/site-packages/pydantic/fields.py:506, in pydantic.fields.ModelField.infer()
#
# File ~/Library/Python/3.8/lib/python/site-packages/pydantic/fields.py:436, in pydantic.fields.ModelField.__init__()
#
# File ~/Library/Python/3.8/lib/python/site-packages/pydantic/fields.py:552, in pydantic.fields.ModelField.prepare()
#
# File ~/Library/Python/3.8/lib/python/site-packages/pydantic/fields.py:668, in pydantic.fields.ModelField._type_analysis()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/typing.py:774, in _GenericAlias.__subclasscheck__(self, cls)
#     772 if self._special:
#     773     if not isinstance(cls, _GenericAlias):
# --> 774         return issubclass(cls, self.__origin__)
#     775     if cls._special:
#     776         return issubclass(cls.__origin__, self.__origin__)
#
# TypeError: issubclass() arg 1 must be a class
